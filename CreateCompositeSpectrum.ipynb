# %% [markdown]
# # Build a quasar composite spectrum

# %% [markdown]
# # About

# %% [markdown]
# This notebook creates a composite quasar spectrum from a collection of quasar spectra.
# The quasar spectra were retrieved from the *Sloan Digital Sky Survey* database DR 12 (http://skyserver.sdss.org/dr12/en/home.aspx) and stored in FITS files.
#
# The notebook reads all FITS files in the given folder, corrects each individual spectrum for redshift (from observed frame to emitted frame), then re-bin-s the data in bins of a user-defined size. It then continues by calculating normalisation factors for each spectrum by the reciprocal of the division of the average spectral flux density in the overlapping region by the average spectral flux density of the adjacent (in the redshift range) spectrum in the same overlapping region.
# Finally, all spectra are combined to one composite spectrum by calculating the *geometric* mean value of all values in a bin, for each bin.

# %% [markdown]
# ## Credits

# %% [markdown]
# This notebook and associated Python modules were developed as part of a group project within the context of module S382 Astrophysics, lectured at the Open University in the UK (http://www.open.ac.uk/courses/modules/s382).

# %% [markdown]
# ## Initialise

# %% [markdown]
# Auto reload libraries, use inline plots

# %%
# %load_ext autoreload
#%matplotlib inline

# %% [markdown]
# Import the libraries

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tic
import os

# %% [markdown]
# ## Create a query for selecting 100 spectra between z = 0.1 and z = 6.9

# %%
num_bins = 100
min_x = 0.1
max_x = 6.9
delta_x = (max_x-min_x)/num_bins

for i in range(1, num_bins):
    left_x = i*delta_x - 0.01
    right_x = i*delta_x + 0.01

    print("SELECT TOP 1 bestObjId, plate, mjd, fiberid")
    print("FROM SpecObj")
    print("WHERE class='QSO'")
    print("AND bestObjId>0")
    print("AND zWarning=0")
    print("AND z BETWEEN {0:.2f} AND {1:.2f}".format(left_x, right_x))
    print("UNION")

i = num_bins
left_x = i*delta_x - 0.01
right_x = i*delta_x + 0.01
print("SELECT TOP 1 bestObjId, plate, mjd, fiberid")
print("FROM SpecObj")
print("WHERE class='QSO'")
print("AND bestObjId>0")
print("AND zWarning=0")
print("AND z BETWEEN {0:.2f} AND {1:.2f}".format(left_x, right_x))

# %% [markdown]
# ## Query the database

# %% [markdown]
# Copy & Paste the generated SQL query in the *Skyserver SQL Search* box at http://skyserver.sdss.org/dr12/en/tools/search/sql.aspx.
#
# Next, download all FITS files - most easily done using the *Bulk Optical Spectra Search* at http://mirror.sdss3.org/bulkSpectra.

# %% [markdown]
# ## Create a composite spectrum using homebrewn routines

# %%
# %autoreload
import hkCompositeSpectrum as hsc

#
# Create composite spectrum
#
binSize = 4.
foldername = "./FITS/"

# Store the names of fits-files
filenameList = []
for filename in os.listdir(foldername):
    if filename.endswith(".fits"):
        filenameList.append(foldername + filename)

# Create the composite spectrum
compositeSpectrum = hsc.CombineSpectra(filenameList, binSize = 4., method="GM")

# Store in CSV file
filename = './FITS/hkCompositeSpectrum.csv'
print("Writing composite spectrum to " + filename)
compositeSpectrum.to_csv(filename)
print("Done...")
# Out:
# Processing: ./FITS/spec-6796-56453-0619.fits...
# Processing: ./FITS/spec-4046-55605-0120.fits...
# Processing: ./FITS/spec-6636-56367-0706.fits...
# Processing: ./FITS/spec-4392-55833-0700.fits...
# Processing: ./FITS/spec-4266-55486-0028.fits...
# Processing: ./FITS/spec-1467-53115-0442.fits...
# Processing: ./FITS/spec-5293-55953-0794.fits...
# Processing: ./FITS/spec-5732-56326-0378.fits...
# Processing: ./FITS/spec-4421-55858-0044.fits...
# Processing: ./FITS/spec-3765-55508-0074.fits...
# Processing: ./FITS/spec-2366-53741-0470.fits...
# Processing: ./FITS/spec-6619-56371-0210.fits...
# Processing: ./FITS/spec-1020-52721-0286.fits...
# Processing: ./FITS/spec-6421-56274-0206.fits...
# Processing: ./FITS/spec-5427-56001-0380.fits...
# Processing: ./FITS/spec-5461-56018-0574.fits...
# Processing: ./FITS/spec-6121-56187-0167.fits...
# Processing: ./FITS/spec-4551-55569-0336.fits...
# Processing: ./FITS/spec-1407-52886-0328.fits...
# Processing: ./FITS/spec-1375-53084-0424.fits...
# Processing: ./FITS/spec-5377-55957-0261.fits...
# Processing: ./FITS/spec-7095-56625-0792.fits...
# Processing: ./FITS/spec-5966-56101-0832.fits...
# Processing: ./FITS/spec-3589-55186-0414.fits...
# Processing: ./FITS/spec-4656-55828-0923.fits...
# Processing: ./FITS/spec-6480-56340-0736.fits...
# Processing: ./FITS/spec-4200-55499-0344.fits...
# Processing: ./FITS/spec-0489-51930-0196.fits...
# Processing: ./FITS/spec-6439-56358-0274.fits...
# Processing: ./FITS/spec-5109-55892-0580.fits...
# Processing: ./FITS/spec-4997-55738-0262.fits...
# Processing: ./FITS/spec-2091-53447-0422.fits...
# Processing: ./FITS/spec-4486-55588-0282.fits...
# Processing: ./FITS/spec-6782-56273-0926.fits...
# Processing: ./FITS/spec-5335-56013-0998.fits...
# Processing: ./FITS/spec-7106-56663-0922.fits...
# Processing: ./FITS/spec-6467-56270-0884.fits...
# Processing: ./FITS/spec-2757-54509-0132.fits...
# Processing: ./FITS/spec-0285-51930-0226.fits...
# Processing: ./FITS/spec-4762-55888-0974.fits...
# Processing: ./FITS/spec-1778-53883-0484.fits...
# Processing: ./FITS/spec-4567-55589-0120.fits...
# Processing: ./FITS/spec-1001-52670-0505.fits...
# Processing: ./FITS/spec-6674-56416-0626.fits...
# Processing: ./FITS/spec-7408-56780-0346.fits...
# Processing: ./FITS/spec-6002-56104-0066.fits...
# Processing: ./FITS/spec-7240-56665-0871.fits...
# Processing: ./FITS/spec-1741-53052-0160.fits...
# Processing: ./FITS/spec-6414-56306-0390.fits...
# Processing: ./FITS/spec-5016-55709-0288.fits...
# Processing: ./FITS/spec-2207-53558-0417.fits...
# Processing: ./FITS/spec-7393-56749-0388.fits...
# Processing: ./FITS/spec-6278-56266-0502.fits...
# Processing: ./FITS/spec-5860-56046-0130.fits...
# Processing: ./FITS/spec-6034-56103-0390.fits...
# Processing: ./FITS/spec-2014-53460-0387.fits...
# Processing: ./FITS/spec-5113-55924-0806.fits...
# Processing: ./FITS/spec-4349-55803-0856.fits...
# Processing: ./FITS/spec-7307-56720-0302.fits...
# Processing: ./FITS/spec-0490-51929-0473.fits...
# Processing: ./FITS/spec-5157-55923-0294.fits...
# Processing: ./FITS/spec-1161-52703-0190.fits...
# Processing: ./FITS/spec-5900-56043-0619.fits...
# Processing: ./FITS/spec-4005-55325-0532.fits...
# Processing: ./FITS/spec-5017-55715-0623.fits...
# Processing: ./FITS/spec-5022-55827-0309.fits...
# Processing: ./FITS/spec-5484-56039-0926.fits...
# Processing: ./FITS/spec-7393-56749-0852.fits...
# Processing: ./FITS/spec-5162-55893-0302.fits...
# Processing: ./FITS/spec-7402-56810-0863.fits...
# Processing: ./FITS/spec-5994-56101-0576.fits...
# Processing: ./FITS/spec-6594-56272-0006.fits...
# Processing: ./FITS/spec-4715-55653-0702.fits...
# Processing: ./FITS/spec-1222-52763-0262.fits...
# Processing: ./FITS/spec-1649-53149-0179.fits...
# Processing: ./FITS/spec-6823-56687-0442.fits...
# Processing: ./FITS/spec-6424-56272-0984.fits...
# Processing: ./FITS/spec-6297-56218-0238.fits...
# Processing: ./FITS/spec-0270-51909-0516.fits...
# Processing: ./FITS/spec-6023-56069-0230.fits...
# Processing: ./FITS/spec-0690-52261-0302.fits...
# Processing: ./FITS/spec-7030-56448-0906.fits...
# Processing: ./FITS/spec-7339-56799-0544.fits...
# Processing: ./FITS/spec-6672-56386-0650.fits...
# Processing: ./FITS/spec-1756-53080-0182.fits...
# Processing: ./FITS/spec-0624-52377-0454.fits...
# Processing: ./FITS/spec-4881-55733-0010.fits...
# Processing: ./FITS/spec-7124-56720-0222.fits...
# Processing: ./FITS/spec-5809-56353-0974.fits...
# Processing: ./FITS/spec-6264-56223-0245.fits...
# Processing: ./FITS/spec-6427-56328-0609.fits...
# Processing: ./FITS/spec-4537-55806-0639.fits...
# Processing: ./FITS/spec-4446-55589-0346.fits...
# Processing: ./FITS/spec-5868-56045-0376.fits...
# Processing: ./FITS/spec-1796-53884-0383.fits...
# Processing: ./FITS/spec-7104-56711-0992.fits...
# Processing: ./FITS/spec-4629-55630-0792.fits...
# Processing: ./FITS/spec-5190-56077-0026.fits...
# Processing: ./FITS/spec-1707-53885-0059.fits...
# Processing: ./FITS/spec-6469-56328-0550.fits...
# Processing: ./FITS/spec-5171-56038-0972.fits...
# Processing: ./FITS/spec-6274-56550-0375.fits...
# Processing: ./FITS/spec-4496-55544-0565.fits...
# Processing: ./FITS/spec-6471-56309-0040.fits...
# Processing: ./FITS/spec-1974-53430-0287.fits...
# Processing: ./FITS/spec-6476-56358-0626.fits...
# Processing: ./FITS/spec-6191-56248-0844.fits...
# Processing: ./FITS/spec-4710-55707-0842.fits...
# Processing: ./FITS/spec-5771-56011-0798.fits...
# Processing: ./FITS/spec-6684-56412-0868.fits...
# Processing: ./FITS/spec-6795-56425-0606.fits...
# Processing: ./FITS/spec-3830-55574-0080.fits...
# Processing: ./FITS/spec-6706-56385-0620.fits...
# Processing: ./FITS/spec-6140-56189-0354.fits...
# Processing: ./FITS/spec-5003-55715-0724.fits...
# Processing: ./FITS/spec-0619-52056-0135.fits...
# Processing: ./FITS/spec-5383-56013-0868.fits...
# Processing: ./FITS/spec-6298-56208-0022.fits...
# Processing: ./FITS/spec-2431-53818-0346.fits...
# Processing: ./FITS/spec-6448-56365-0232.fits...
# Processing: ./FITS/spec-4389-55539-0898.fits...
# Processing: ./FITS/spec-7280-56709-0772.fits...
# Processing: ./FITS/spec-6416-56312-0944.fits...
# Processing: ./FITS/spec-4711-55737-0524.fits...
# Processing: ./FITS/spec-3735-55209-0140.fits...
# Processing: ./FITS/spec-5186-56337-0586.fits...
# Processing: ./FITS/spec-5150-56329-0276.fits...
# Processing: ./FITS/spec-5174-56047-0674.fits...
# Processing: ./FITS/spec-1590-52974-0498.fits...
# Processing: ./FITS/spec-2016-53799-0577.fits...
# Processing: ./FITS/spec-1272-52989-0019.fits...
# Processing: ./FITS/spec-1699-53148-0535.fits...
# Processing: ./FITS/spec-6142-56219-1000.fits...
# Processing: ./FITS/spec-7383-56749-0902.fits...
# Processing: ./FITS/spec-6719-56390-0015.fits...
# Processing: ./FITS/spec-6175-56265-0742.fits...
# Processing: ./FITS/spec-1305-52757-0378.fits...
# Processing: ./FITS/spec-3793-55214-0776.fits...
# Processing: ./FITS/spec-0608-52081-0605.fits...
# Processing: ./FITS/spec-1217-52672-0502.fits...
# Processing: ./FITS/spec-7096-56683-0740.fits...
# Processing: ./FITS/spec-2269-53711-0163.fits...
# Processing: ./FITS/spec-7294-56739-0626.fits...
# Processing: ./FITS/spec-3975-55321-0179.fits...
# Processing: ./FITS/spec-0602-52072-0416.fits...
# Processing: ./FITS/spec-3858-55273-0034.fits...
# Processing: ./FITS/spec-6982-56444-0110.fits...
# Processing: ./FITS/spec-4188-55684-0934.fits...
# Processing: ./FITS/spec-5398-56011-0808.fits...
# Processing: ./FITS/spec-7316-56710-0054.fits...
# Processing: ./FITS/spec-2099-53469-0024.fits...
# Processing: ./FITS/spec-2033-53476-0129.fits...
# Processing: ./FITS/spec-4349-55803-0598.fits...
# Processing: ./FITS/spec-7376-56749-0577.fits...
# Processing: ./FITS/spec-7118-56686-0310.fits...
# Processing: ./FITS/spec-5364-56000-0186.fits...
# Processing: ./FITS/spec-1742-53053-0404.fits...
# Processing: ./FITS/spec-6827-56428-0374.fits...
# Processing: ./FITS/spec-2767-54243-0122.fits...
# Processing: ./FITS/spec-4447-55542-0138.fits...
# Processing: ./FITS/spec-6300-56449-0192.fits...
# Processing: ./FITS/spec-5211-56002-0194.fits...
# Processing: ./FITS/spec-4648-55673-0734.fits...
# Processing: ./FITS/spec-0686-52519-0337.fits...
# Processing: ./FITS/spec-0912-52427-0517.fits...
# Processing: ./FITS/spec-0916-52378-0406.fits...
# Processing: ./FITS/spec-1702-53144-0067.fits...
# Processing: ./FITS/spec-6800-56399-0096.fits...
# Processing: ./FITS/spec-7380-56753-0283.fits...
# Processing: ./FITS/spec-4781-55653-0836.fits...
# Processing: ./FITS/spec-6642-56396-0874.fits...
# Processing: ./FITS/spec-4835-56016-0152.fits...
# Processing: ./FITS/spec-6457-56330-0521.fits...
# Processing: ./FITS/spec-2204-53877-0324.fits...
# Processing: ./FITS/spec-6452-56366-0860.fits...
# Processing: ./FITS/spec-7378-56715-0990.fits...
# Processing: ./FITS/spec-7117-56685-0978.fits...
# Processing: ./FITS/spec-1839-53471-0429.fits...
# Processing: ./FITS/spec-6260-56568-0898.fits...
# Processing: ./FITS/spec-2115-53535-0157.fits...
# Processing: ./FITS/spec-2646-54479-0398.fits...
# Processing: ./FITS/spec-6780-56577-0310.fits...
# Processing: ./FITS/spec-5356-55979-0698.fits...
# Processing: ./FITS/spec-4501-55590-0798.fits...
# Processing: ./FITS/spec-6721-56398-0716.fits...
# Processing: ./FITS/spec-5386-56008-0238.fits...
# Wavelength range: [500, 9.5E+03]
# Correcting for redshift, and rebinning spectra...
#    Processing z = 3.32
#    Processing z = 2.85
#    Processing z = 1.24
#    Processing z = 3.19
#    Processing z = 2.3
#    Processing z = 3.25
#    Processing z = 1.89
#    Processing z = 0.47
#    Processing z = 2.3
#    Processing z = 2.44
#    Processing z = 1.18
#    Processing z = 0.94
#    Processing z = 0.33
#    Processing z = 0.52
#    Processing z = 3.09
#    Processing z = 2.56
#    Processing z = 2.23
#    Processing z = 0.81
#    Processing z = 1.15
#    Processing z = 0.06
#    Processing z = 1.42
#    Processing z = 0.6
#    Processing z = 2.98
#    Processing z = 0.67
#    Processing z = 3.16
#    Processing z = 2.04
#    Processing z = 3.32
#    Processing z = 1.31
#    Processing z = 2.1
#    Processing z = 0.45
#    Processing z = 0.65
#    Processing z = 0.53
#    Processing z = 2.78
#    Processing z = 1.77
#    Processing z = 2.76
#    Processing z = 1.77
#    Processing z = 0.6
#    Processing z = 0.0601
#    Processing z = 1.55
#    Processing z = 3.29
#    Processing z = 1.51
#    Processing z = 0.45
#    Processing z = 1.76
#    Processing z = 1.01
#    Processing z = 1.28
#    Processing z = 0.65
#    Processing z = 2.03
#    Processing z = 1.69
#    Processing z = 0.72
#    Processing z = 2.96
#    Processing z = 1.21
#    Processing z = 1.55
#    Processing z = 2.98
#    Processing z = 3.22
#    Processing z = 0.32
#    Processing z = 0.78
#    Processing z = 2.63
#    Processing z = 3.16
#    Processing z = 1.08
#    Processing z = 1.9
#    Processing z = 1.42
#    Processing z = 0.13
#    Processing z = 2.51
#    Processing z = 2.7
#    Processing z = 1.69
#    Processing z = 3.19
#    Processing z = 2.78
#    Processing z = 1.21
#    Processing z = 2.76
#    Processing z = 1.15
#    Processing z = 2.63
#    Processing z = 1.05
#    Processing z = 3.03
#    Processing z = 0.98
#    Processing z = 1.57
#    Processing z = 3.03
#    Processing z = 1.84
#    Processing z = 1.49
#    Processing z = 0.33
#    Processing z = 2.43
#    Processing z = 1.01
#    Processing z = 0.74
#    Processing z = 2.5
#    Processing z = 1.51
#    Processing z = 1.57
#    Processing z = 1.44
#    Processing z = 2.03
#    Processing z = 2.85
#    Processing z = 1.96
#    Processing z = 0.52
#    Processing z = 2.17
#    Processing z = 0.4
#    Processing z = 1.64
#    Processing z = 3.05
#    Processing z = 0.4
#    Processing z = 1.35
#    Processing z = 0.85
#    Processing z = 2.17
#    Processing z = 0.47
#    Processing z = 2.23
#    Processing z = 3.25
#    Processing z = 0.87
#    Processing z = 0.12
#    Processing z = 2.51
#    Processing z = 1.84
#    Processing z = 1.44
#    Processing z = 1.96
#    Processing z = 0.53
#    Processing z = 3.12
#    Processing z = 1.24
#    Processing z = 1.76
#    Processing z = 3.12
#    Processing z = 1.11
#    Processing z = 0.91
#    Processing z = 3.09
#    Processing z = 0.12
#    Processing z = 2.04
#    Processing z = 2.57
#    Processing z = 0.25
#    Processing z = 0.74
#    Processing z = 2.37
#    Processing z = 1.11
#    Processing z = 1.89
#    Processing z = 3.39
#    Processing z = 1.05
#    Processing z = 2.56
#    Processing z = 0.58
#    Processing z = 2.96
#    Processing z = 1.49
#    Processing z = 3.22
#    Processing z = 0.26
#    Processing z = 1.18
#    Processing z = 2.71
#    Processing z = 1.9
#    Processing z = 1.35
#    Processing z = 2.83
#    Processing z = 0.91
#    Processing z = 0.87
#    Processing z = 0.94
#    Processing z = 0.39
#    Processing z = 3.29
#    Processing z = 0.26
#    Processing z = 0.67
#    Processing z = 2.91
#    Processing z = 1.08
#    Processing z = 1.71
#    Processing z = 0.81
#    Processing z = 0.85
#    Processing z = 2.83
#    Processing z = 0.72
#    Processing z = 0.25
#    Processing z = 1.28
#    Processing z = 2.43
#    Processing z = 2.1
#    Processing z = 2.5
#    Processing z = 3.39
#    Processing z = 0.13
#    Processing z = 1.83
#    Processing z = 1.97
#    Processing z = 0.78
#    Processing z = 0.98
#    Processing z = 2.91
#    Processing z = 2.64
#    Processing z = 0.58
#    Processing z = 0.19
#    Processing z = 0.32
#    Processing z = 0.39
#    Processing z = 1.38
#    Processing z = 1.71
#    Processing z = 2.7
#    Processing z = 2.89
#    Processing z = 2.64
#    Processing z = 2.57
#    Processing z = 0.19
#    Processing z = 2.89
#    Processing z = 1.64
#    Processing z = 1.31
#    Processing z = 1.83
#    Processing z = 2.44
#    Processing z = 1.38
#    Processing z = 1.62
#    Processing z = 1.97
#    Processing z = 2.37
#    Processing z = 3.05
#    Processing z = 1.62
#    Processing z = 2.71
# Sorting arrays by redshift...
# Calculating normalisation factors...
#    Processing redshift: z = 0.06
#    Processing redshift: z = 0.0601
#    Processing redshift: z = 0.12
#    Processing redshift: z = 0.12
#    Processing redshift: z = 0.13
#    Processing redshift: z = 0.13
#    Processing redshift: z = 0.19
#    Processing redshift: z = 0.19
#    Processing redshift: z = 0.25
#    Processing redshift: z = 0.25
#    Processing redshift: z = 0.26
#    Processing redshift: z = 0.26
#    Processing redshift: z = 0.32
#    Processing redshift: z = 0.32
#    Processing redshift: z = 0.33
#    Processing redshift: z = 0.33
#    Processing redshift: z = 0.39
#    Processing redshift: z = 0.39
#    Processing redshift: z = 0.4
#    Processing redshift: z = 0.4
#    Processing redshift: z = 0.45
#    Processing redshift: z = 0.45
#    Processing redshift: z = 0.47
#    Processing redshift: z = 0.47
#    Processing redshift: z = 0.52
#    Processing redshift: z = 0.52
#    Processing redshift: z = 0.53
#    Processing redshift: z = 0.53
#    Processing redshift: z = 0.58
#    Processing redshift: z = 0.58
#    Processing redshift: z = 0.6
#    Processing redshift: z = 0.6
#    Processing redshift: z = 0.65
#    Processing redshift: z = 0.65
#    Processing redshift: z = 0.67
#    Processing redshift: z = 0.67
#    Processing redshift: z = 0.72
#    Processing redshift: z = 0.72
#    Processing redshift: z = 0.74
#    Processing redshift: z = 0.74
#    Processing redshift: z = 0.78
#    Processing redshift: z = 0.78
#    Processing redshift: z = 0.81
#    Processing redshift: z = 0.81
#    Processing redshift: z = 0.85
#    Processing redshift: z = 0.85
#    Processing redshift: z = 0.87
#    Processing redshift: z = 0.87
#    Processing redshift: z = 0.91
#    Processing redshift: z = 0.91
#    Processing redshift: z = 0.94
#    Processing redshift: z = 0.94
#    Processing redshift: z = 0.98
#    Processing redshift: z = 0.98
#    Processing redshift: z = 1.01
#    Processing redshift: z = 1.01
#    Processing redshift: z = 1.05
#    Processing redshift: z = 1.05
#    Processing redshift: z = 1.08
#    Processing redshift: z = 1.08
#    Processing redshift: z = 1.11
#    Processing redshift: z = 1.11
#    Processing redshift: z = 1.15
#    Processing redshift: z = 1.15
#    Processing redshift: z = 1.18
#    Processing redshift: z = 1.18
#    Processing redshift: z = 1.21
#    Processing redshift: z = 1.21
#    Processing redshift: z = 1.24
#    Processing redshift: z = 1.24
#    Processing redshift: z = 1.28
#    Processing redshift: z = 1.28
#    Processing redshift: z = 1.31
#    Processing redshift: z = 1.31
#    Processing redshift: z = 1.35
#    Processing redshift: z = 1.35
#    Processing redshift: z = 1.38
#    Processing redshift: z = 1.38
#    Processing redshift: z = 1.42
#    Processing redshift: z = 1.42
#    Processing redshift: z = 1.44
#    Processing redshift: z = 1.44
#    Processing redshift: z = 1.49
#    Processing redshift: z = 1.49
#    Processing redshift: z = 1.51
#    Processing redshift: z = 1.51
#    Processing redshift: z = 1.55
#    Processing redshift: z = 1.55
#    Processing redshift: z = 1.57
#    Processing redshift: z = 1.57
#    Processing redshift: z = 1.62
#    Processing redshift: z = 1.62
#    Processing redshift: z = 1.64
#    Processing redshift: z = 1.64
#    Processing redshift: z = 1.69
#    Processing redshift: z = 1.69
#    Processing redshift: z = 1.71
#    Processing redshift: z = 1.71
#    Processing redshift: z = 1.76
#    Processing redshift: z = 1.76
#    Processing redshift: z = 1.77
#    Processing redshift: z = 1.77
#    Processing redshift: z = 1.83
#    Processing redshift: z = 1.83
#    Processing redshift: z = 1.84
#    Processing redshift: z = 1.84
#    Processing redshift: z = 1.89
#    Processing redshift: z = 1.89
#    Processing redshift: z = 1.9
#    Processing redshift: z = 1.9
#    Processing redshift: z = 1.96
#    Processing redshift: z = 1.96
#    Processing redshift: z = 1.97
#    Processing redshift: z = 1.97
#    Processing redshift: z = 2.03
#    Processing redshift: z = 2.03
#    Processing redshift: z = 2.04
#    Processing redshift: z = 2.04
#    Processing redshift: z = 2.1
#    Processing redshift: z = 2.1
#    Processing redshift: z = 2.17
#    Processing redshift: z = 2.17
#    Processing redshift: z = 2.23
#    Processing redshift: z = 2.23
#    Processing redshift: z = 2.3
#    Processing redshift: z = 2.3
#    Processing redshift: z = 2.37
#    Processing redshift: z = 2.37
#    Processing redshift: z = 2.43
#    Processing redshift: z = 2.43
#    Processing redshift: z = 2.44
#    Processing redshift: z = 2.44
#    Processing redshift: z = 2.5
#    Processing redshift: z = 2.5
#    Processing redshift: z = 2.51
#    Processing redshift: z = 2.51
#    Processing redshift: z = 2.56
#    Processing redshift: z = 2.56
#    Processing redshift: z = 2.57
#    Processing redshift: z = 2.57
#    Processing redshift: z = 2.63
#    Processing redshift: z = 2.63
#    Processing redshift: z = 2.64
#    Processing redshift: z = 2.64
#    Processing redshift: z = 2.7
#    Processing redshift: z = 2.7
#    Processing redshift: z = 2.71
#    Processing redshift: z = 2.71
#    Processing redshift: z = 2.76
#    Processing redshift: z = 2.76
#    Processing redshift: z = 2.78
#    Processing redshift: z = 2.78
#    Processing redshift: z = 2.83
#    Processing redshift: z = 2.83
#    Processing redshift: z = 2.85
#    Processing redshift: z = 2.85
#    Processing redshift: z = 2.89
#    Processing redshift: z = 2.89
#    Processing redshift: z = 2.91
#    Processing redshift: z = 2.91
#    Processing redshift: z = 2.96
#    Processing redshift: z = 2.96
#    Processing redshift: z = 2.98
#    Processing redshift: z = 2.98
#    Processing redshift: z = 3.03
#    Processing redshift: z = 3.03
#    Processing redshift: z = 3.05
#    Processing redshift: z = 3.05
#    Processing redshift: z = 3.09
#    Processing redshift: z = 3.09
#    Processing redshift: z = 3.12
#    Processing redshift: z = 3.12
#    Processing redshift: z = 3.16
#    Processing redshift: z = 3.16
#    Processing redshift: z = 3.19
#    Processing redshift: z = 3.19
#    Processing redshift: z = 3.22
#    Processing redshift: z = 3.22
#    Processing redshift: z = 3.25
#    Processing redshift: z = 3.25
#    Processing redshift: z = 3.29
#    Processing redshift: z = 3.29
#    Processing redshift: z = 3.32
#    Processing redshift: z = 3.32
#    Processing redshift: z = 3.39
# Normalisation factors:  [0.022889185642552157, 0.0084681311810896991, 0.40023682881740374, 0.065389022298015145, 0.039571700039869623, 0.029529693180872209, 0.085407882677187921, 0.060854435277680495, 0.11556273030748961, 0.085019225837947132, 0.033591941941202422, 0.079141872774724398, 0.19448968320179957, 0.074918303423816196, 0.12651816190063794, 0.061622973207646099, 0.086279725023360787, 0.088004876235065047, 0.10614804163090019, 0.9491712912309247, 0.28385167972187925, 0.48049456972479421, 0.1143889602894079, 0.21479443087328842, 0.70777893195629038, 0.17952302621356817, 0.16515527678733444, 0.38933480750308908, 0.29205435951960523, 0.30748991759975552, 0.12235933986273841, 0.16409190267840223, 0.34782712514231473, 0.34128140207139884, 1.2951903901437869, 0.52274939804294607, 1.5969884078939554, 0.35040801943519273, 0.88366357853586786, 0.16699036814171844, 0.091957323170983526, 1.7838243789249475, 0.3971960088565088, 0.68056376618664649, 0.47994533136202816, 3.9906361168210895, 0.6321408629884282, 0.57480987736378186, 0.10768729356505527, 0.57817576480681721, 0.1546062322720432, 0.37191586292044942, 0.041219954971232112, 0.86798782054033596, 0.34500951993830054, 0.26418071027796136, 4.267456548444108, 0.64390411888290899, 0.39922878604305678, 0.041506793042511717, 0.55480543988912856, 0.83215483691957925, 0.29529331580334295, 0.67480889116870224, 0.096689138625582649, 0.042678240754345884, 0.56661908473840406, 0.096296770484088495, 1.7454187290309164, 0.62324391489639552, 0.12432584741798969, 2.9342532182320911, 0.35181279707003549, 0.34520451525040746, 0.27745496277538789, 0.2270905142015581, 0.077441785202146243, 0.55107006872440445, 1.320904906696954, 1.1063583600490057, 1.0289122487368865, 0.098148372684791707, 0.40641280313465639, 2.5606523415972968, 0.10465447894069936, 0.6217699200803144, 0.19843611604140926, 0.84975177924668632, 0.27667268950251078, 0.089443361917342493, 0.20209654706173702, 0.20804188681629657, 1.366349746708369, 1.5379536182027624, 0.084385950303206961, 6.3590660910541903, 1.0281909062815893, 1.3358340840333751, 0.57239923766674727, 0.16218217950875702, 0.44095226685314337, 3.2476477970969593, 0.18978943896099623, 0.36997971468607116, 0.27361975536723099, 0.4829592974405425, 0.52114790555552104, 0.16755272648100919, 1.3077973741075868, 0.19853996439354918, 0.10938295075147998, 1.4839087061667815, 2.4324719186624661, 0.17868737400268969, 5.4848022208296676, 1.6357815299537561, 1.2802483294040112, 0.044401631322143628, 0.27979287658326685, 2.8095222137776563, 0.54884370912221736, 0.83322412712719129, 5.3968795396434563, 0.39517190388425055, 0.61318699442904367, 5.8821525949852136, 0.79771845986958267, 0.90894282684058814, 1.5695069443376644, 1.1433858512251207, 2.0515843893740238, 0.88521746113384947, 0.66316656145670372, 0.13129176140962043, 1.9425057132042916, 0.34643411002804897, 1.09750145123099, 2.8739858860302792, 0.69064078221631997, 1.3727589701038385, 0.76871269479874671, 0.54842788799268827, 0.61124117539023759, 1.5259677052778438, 1.1623365783195116, 3.0962745294865988, 0.61150710776897221, 1.7256508492900025, 1.4491364210941122, 0.99140453708629306, 0.39032545888099018, 1.2053138890209971, 1.7700717029864195, 0.98170526011221559, 0.3566583064886204, 2.1991353808444756, 1.0040408149104154, 0.9160913064913796, 3.9396431898643409, 0.60057815286918936, 3.7199920093163863, 2.5788154705022124, 2.6312511462857517, 0.33617523082515172, 0.56284849184296171, 0.87007935959261529, 1.4334799759221841, 1.6411120574173881, 1.0271359679456586, 1.5749115425349285, 1.5651245403194465, 0.7897050695832718, 0.66729214741651732, 2.2489264872682959, 2.2076059580361567, 2.6592609989525733, 0.18572643116184334, 0.54014416593930137, 0.51802697028319911, 0.78759028400151021, 0.63127286366379398, 1.7941929380859847, 2.3722035980228275, 1.0465848251097956, 1.7021341679359845, 1.0]
# Creating composite spectrum...
# Writing composite spectrum to ./FITS/hkCompositeSpectrum.csv
# Done...

# %% [markdown]
# ## Plot the composite spectrum, including common emission lines

# %%
# %autoreload
import hkSpectrumLines as hsl

#
# Plot the spectrum
#

# Create a figure with axes
fig = plt.figure()
ax0 = fig.add_subplot(1, 1, 1)

# Plot the composite spectrum
ax0.plot(compositeSpectrum['wavelength'], compositeSpectrum['flux'], linewidth=1)

# Plot spectrum lines
hsl.PlotSpectrumLines(ax0,[r'Ly$\alpha$', 'C IV', 'C III]', 'Mg II', r'H$\beta$', '[O III]', r'H$\alpha$'])

# Set limits for axes
#ax0.set_xlim(1000,8500)
#ax0.set_ylim(0, 1800)

# Create labels for axes
ax0.set_xlabel('Wavelength $\lambda / \AA$', fontsize='large')
ax0.set_ylabel('Spectral flux density $f_{\lambda} \, / $ Arbitrary units', fontsize='large')

# Create a title
ax0.set_title('Spectral flux densities for composite spectrum of quasar', fontsize='xx-large')

# Display a grid
ax0.grid(True)

# Set the tick marks
xMajorLocator = tic.MultipleLocator(500)
xMinorLocator = tic.AutoMinorLocator(5)
ax0.xaxis.set_major_locator(xMajorLocator)
ax0.xaxis.set_minor_locator(xMinorLocator)

yMinorLocator = tic.AutoMinorLocator(5)
ax0.yaxis.set_minor_locator(yMinorLocator)

ax0.tick_params(which = 'both', direction = 'in')

# Display the plot
plt.show()

# %% [markdown]
# ## Create a log-log plot of the composite spectrum

# %%
#
# Plot the spectrum in loglog scale
#

# Create a figure with axes
fig = plt.figure()
ax0 = fig.add_subplot(1, 1, 1)

# Plot the composite spectrum
ax0.loglog(compositeSpectrum['wavelength'], compositeSpectrum['flux'], linewidth=1)

# Set limits for axes
#ax0.set_xlim(1000,8500)
#ax0.set_ylim(0, 1800)

# Create labels for axes
ax0.set_xlabel('Wavelength $\lambda / \AA$', fontsize='large')
ax0.set_ylabel('Spectral flux density $f_{\lambda} \, / $ Arbitrary units', fontsize='large')

# Create a title
ax0.set_title('Spectral flux densities for composite spectrum of quasar', fontsize='xx-large')

# Display a grid
ax0.grid(True)

# Set the tick marks
xMajorLocator = tic.MultipleLocator(500)
xMinorLocator = tic.AutoMinorLocator(5)
ax0.xaxis.set_major_locator(xMajorLocator)
ax0.xaxis.set_minor_locator(xMinorLocator)

yMinorLocator = tic.AutoMinorLocator(5)
ax0.yaxis.set_minor_locator(yMinorLocator)

ax0.tick_params(which = 'both', direction = 'in')

# Display the plot
plt.show()
